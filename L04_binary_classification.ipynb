# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm
X = np.concatenate([norm.rvs(loc=5, scale=1.5, size=(20, 2)),
                    norm.rvs(loc=1, scale=1.5, size=(20, 2))], axis=0)
y = np.zeros(X.shape[0])
y[20:] = 1

plt.figure(figsize=(5, 5), dpi=100)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)
classifier.fit(X, y)

h = .5
x_min, x_max = X[:, 0].min() - h, X[:, 0].max() + h
y_min, y_max = X[:, 1].min() - h, X[:, 1].max() + h
h = .05
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                      np.arange(y_min, y_max, h))
Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 5), dpi=100)
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.axis([x_min, x_max, y_min, y_max])
plt.subplot(1, 2, 2)
plt.contourf(xx, yy, Z, alpha=.3, cmap='coolwarm')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.axis([x_min, x_max, y_min, y_max])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(max_depth=3)
classifier.fit(X, y)

Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 5), dpi=100)
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.axis([x_min, x_max, y_min, y_max])
plt.subplot(1, 2, 2)
plt.contourf(xx, yy, Z, alpha=.3, cmap='coolwarm')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.axis([x_min, x_max, y_min, y_max])
plt.show()

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_data = export_graphviz(classifier, out_file=None, feature_names=None, 
                           class_names=None, filled=True,
                           rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X, y)

Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 5), dpi=100)
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.axis([x_min, x_max, y_min, y_max])
plt.subplot(1, 2, 2)
plt.contourf(xx, yy, Z, alpha=.3, cmap='coolwarm')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.axis([x_min, x_max, y_min, y_max])
plt.show()
